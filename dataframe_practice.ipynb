# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Spectrum_30_days.csv")

# %%
df1 = df.copy()

# %%
df1['provider_id']= df1['provider_id'].astype(object)

# %%
df1.drop('created_by_id', axis=1, inplace=True)

# %%
#df1[df1['address_1b'].isna()]
# Out:
#          id           created_at first_name_1 last_name_1        address_1a  \
# 0    375296  2023-09-07 09:02:47       Travis    watkins      517 Seward St
# 4    375329  2023-09-07 12:19:42        james     geffert      18 Carter St
# 5    375351  2023-09-07 16:03:02       Markia      Miller     6 Bexhill Cir
# 6    375371  2023-09-08 06:36:52         Juan    Dejesus     228 Rackley Ln
# 7    375389  2023-09-08 09:11:47      Marilyn      Tucker  2251 Fairview Rd
# ..      ...                  ...          ...         ...               ...
# 219  377343  2023-10-05 05:23:41       Dustin      Clarke     5 Inoko Place
# 220  377367  2023-10-05 09:06:28        Haimy      Nguyen      8714 Edna Pl
# 221  377393  2023-10-05 12:59:27      timothy       alden  113 Farnstead Dr
# 222  377403  2023-10-05 14:11:14     Kimberly        Webb    2318 Rosser Ct
# 226  377486  2023-10-06 13:07:21      Yesenia     Urdiano   12348 Rush St,
#
# ...

# %%
df1['address_1b'] = df1['address_1b'].fillna("NA")

# %%
df1[df1['address_1b']=='NA']
# Out:
#          id           created_at first_name_1 last_name_1        address_1a  \
# 0    375296  2023-09-07 09:02:47       Travis    watkins      517 Seward St
# 4    375329  2023-09-07 12:19:42        james     geffert      18 Carter St
# 5    375351  2023-09-07 16:03:02       Markia      Miller     6 Bexhill Cir
# 6    375371  2023-09-08 06:36:52         Juan    Dejesus     228 Rackley Ln
# 7    375389  2023-09-08 09:11:47      Marilyn      Tucker  2251 Fairview Rd
# ..      ...                  ...          ...         ...               ...
# 219  377343  2023-10-05 05:23:41       Dustin      Clarke     5 Inoko Place
# 220  377367  2023-10-05 09:06:28        Haimy      Nguyen      8714 Edna Pl
# 221  377393  2023-10-05 12:59:27      timothy       alden  113 Farnstead Dr
# 222  377403  2023-10-05 14:11:14     Kimberly        Webb    2318 Rosser Ct
# 226  377486  2023-10-06 13:07:21      Yesenia     Urdiano   12348 Rush St,
#
# ...
